# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('clean_data/Abhishek_2.csv')
data = data['ch_1']

# %%
fs = 128
time = [i/fs for i in range(len(data))]

# %%
plt.figure(figsize=(15,3))
plt.plot(time , data)
plt.xlabel('time_series')
plt.ylabel('Amplitude (uV)')
# plt.title('Raw Signal')
# Out:
# Text(0, 0.5, 'Amplitude (uV)')

# %%
plt.figure(figsize=(15,3))
plt.plot(time , data)
plt.xlabel('time_series')
plt.ylabel('Amplitude (uV)')
plt.title('clean Signal')
# Out:
# Text(0.5, 1.0, 'clean Signal')

# %%
plt.figure(figsize=(15,3))
plt.plot(time , data)
plt.xlabel('time_series')
plt.ylabel('Amplitude (uV)')
plt.title('modified Signal')
# Out:
# Text(0.5, 1.0, 'modified Signal')

# %%
res.keys
# Out:
# <function dict.keys>

# %%
acc = {'tradional Approach': 81.92 , '5 Fold' : 81.92 , '5Fold Ensembler':85.54 }
prec = {'tradional Approach': 63.41 , '5 Fold' : 68.29 , '5Fold Ensembler':70.73 }
rec = {'tradional Approach': 100 , '5 Fold' : 93.33 , '5Fold Ensembler':100 }
plt.figure(figsize=(10,5))
plt.plot(acc.keys() , acc.values() , label = 'Accuracy'  )
plt.plot(prec.keys() , prec.values(), label = 'Precision')
plt.plot(rec.keys() , rec.values() , label = 'Recall')
plt.xlabel('Approach')
plt.legend()
plt.title('Results')
# Out:
# Text(0.5, 1.0, 'Results')

# %%
plt.bar(acc.keys() , acc.values() , color = ('green' , 'orange' , 'blue'))
plt.xlabel('Approach')
plt.ylabel('Accuarcy')
# Out:
# Text(0, 0.5, 'Accuarcy')

# %%
plt.bar(prec.keys() , prec.values() , color = ('green' , 'orange' , 'blue'))
plt.xlabel('Approach')
plt.ylabel('Precision')
# Out:
# Text(0, 0.5, 'Precision')

# %%
plt.bar(rec.keys() , rec.values() , color = ('green' , 'orange' , 'blue'))
plt.xlabel('Approach')
plt.ylabel('Recall')
# Out:
# Text(0, 0.5, 'Recall')
